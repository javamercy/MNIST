# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train = X_train / 255.0
X_test = X_test / 255.0
m, w, h = X_train.shape

X_train = X_train.reshape(-1, w, h, 1)
X_test = X_test.reshape(-1, w, h, 1)

# %%
plt.imshow(X_train[12], cmap="gray")
plt.title(f"Label: {y_train[12]}")

# %%
def make_data_augmentation():
    return tf.keras.Sequential([
        tf.keras.layers.RandomTranslation(height_factor=0.1, width_factor=0.1),
        tf.keras.layers.RandomRotation(factor=0.05),
        tf.keras.layers.RandomZoom(height_factor=0.1, width_factor=0.1)
    ])

# %%
data_augmentation_fcnn = make_data_augmentation()
fcnn = tf.keras.Sequential(
    [
        tf.keras.layers.Input(shape=(w, h, 1)),
        data_augmentation_fcnn,
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(units=256, activation="relu"),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(units=128, activation="relu"),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(units=64, activation="relu"),
        tf.keras.layers.Dense(units=10, activation="softmax")
    ]
)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
loss = tf.keras.losses.SparseCategoricalCrossentropy()
metrics = ["accuracy"]
fcnn.compile(optimizer=optimizer, loss=loss, metrics=metrics)
fcnn_history = fcnn.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))
fcnn.save("fcnn.keras")
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7775 - loss: 0.6884 - val_accuracy: 0.9551 - val_loss: 0.1433
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8818 - loss: 0.3811 - val_accuracy: 0.9566 - val_loss: 0.1330
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9009 - loss: 0.3242 - val_accuracy: 0.9699 - val_loss: 0.0990
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9100 - loss: 0.2941 - val_accuracy: 0.9721 - val_loss: 0.0915
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9153 - loss: 0.2778 - val_accuracy: 0.9675 - val_loss: 0.1029
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9206 - loss: 0.2561 - val_accuracy: 0.9759 - val_loss: 0.0770
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9239 - loss: 0.2493 - val_accuracy: 0.9735 - val_loss: 0.0872
# Epoch 8/20
# ...

# %%
data_augmentation_cnn = make_data_augmentation()
cnn = tf.keras.Sequential(
    [
        tf.keras.Input(shape=(28, 28, 1)),
        data_augmentation_cnn,
        tf.keras.layers.Conv2D(filters=16, kernel_size=(3, 3), padding="same", activation="relu"),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
        tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), padding="same", activation="relu"),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
        tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3), padding="same", activation="relu"),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(units=64, activation="relu"),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(units=10, activation="softmax")
    ]
)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
loss = tf.keras.losses.SparseCategoricalCrossentropy()
metrics = ["accuracy"]
cnn.compile(optimizer=optimizer, loss=loss, metrics=metrics)
cnn_history = cnn.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))
cnn.save("cnn.keras")
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.8877 - loss: 0.3594 - val_accuracy: 0.9782 - val_loss: 0.0637
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9597 - loss: 0.1374 - val_accuracy: 0.9899 - val_loss: 0.0302
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9680 - loss: 0.1082 - val_accuracy: 0.9880 - val_loss: 0.0359
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9732 - loss: 0.0898 - val_accuracy: 0.9899 - val_loss: 0.0339
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9757 - loss: 0.0821 - val_accuracy: 0.9885 - val_loss: 0.0358
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9786 - loss: 0.0715 - val_accuracy: 0.9926 - val_loss: 0.0232
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9804 - loss: 0.0670 - val_accuracy: 0.9861 - val_loss: 0.0463
# Epoch 8/20
# ...

# %%
np.random.shuffle(y_train)

# %%
fcnn_shuffled = tf.keras.Sequential(
    [
        tf.keras.layers.Input(shape=(w, h, 1)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(units=512, activation="relu"),
        tf.keras.layers.Dense(units=256, activation="relu"),
        tf.keras.layers.Dense(units=128, activation="relu"),
        tf.keras.layers.Dense(units=10, activation="softmax")
    ]
)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
loss = tf.keras.losses.SparseCategoricalCrossentropy()
metrics = ["accuracy"]
fcnn_shuffled.compile(optimizer=optimizer, loss=loss, metrics=metrics)
fcnn_shuffled_history = fcnn_shuffled.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
fcnn_shuffled.save("fcnn_shuffled.keras")
# Out:
# Epoch 1/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.1086 - loss: 2.3043 - val_accuracy: 0.1251 - val_loss: 2.3019
# Epoch 2/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.1105 - loss: 2.3022 - val_accuracy: 0.1135 - val_loss: 2.3009
# Epoch 3/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.1106 - loss: 2.3018 - val_accuracy: 0.1135 - val_loss: 2.3063
# Epoch 4/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.1124 - loss: 2.3015 - val_accuracy: 0.1135 - val_loss: 2.3025
# Epoch 5/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.1122 - loss: 2.3011 - val_accuracy: 0.1135 - val_loss: 2.3055
# Epoch 6/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.1119 - loss: 2.3009 - val_accuracy: 0.1135 - val_loss: 2.3095
# Epoch 7/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.1115 - loss: 2.3002 - val_accuracy: 0.1136 - val_loss: 2.3192
# Epoch 8/100
# ...

# %%
cnn_shuffled = tf.keras.Sequential(
    [
        tf.keras.Input(shape=(w, h, 1)),
        tf.keras.layers.Conv2D(filters=16, kernel_size=(3, 3), padding="same", activation="relu"),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
        tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), padding="same", activation="relu"),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
        tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3), padding="same", activation="relu"),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(units=128, activation="relu"),
        tf.keras.layers.Dense(units=10, activation="softmax")
    ]
)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
loss = tf.keras.losses.SparseCategoricalCrossentropy()
metrics = ["accuracy"]
cnn_shuffled.compile(optimizer=optimizer, loss=loss, metrics=metrics)
cnn_shuffled_history = cnn_shuffled.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
cnn_shuffled.save("cnn_shuffled.keras")
# Out:
# Epoch 1/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.1111 - loss: 2.3017 - val_accuracy: 0.1023 - val_loss: 2.3017
# Epoch 2/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.1124 - loss: 2.3016 - val_accuracy: 0.1135 - val_loss: 2.3013
# Epoch 3/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.1124 - loss: 2.3014 - val_accuracy: 0.1135 - val_loss: 2.3011
# Epoch 4/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.1124 - loss: 2.3014 - val_accuracy: 0.1135 - val_loss: 2.3010
# Epoch 5/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.1124 - loss: 2.3014 - val_accuracy: 0.1135 - val_loss: 2.3012
# Epoch 6/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.1124 - loss: 2.3014 - val_accuracy: 0.1135 - val_loss: 2.3012
# Epoch 7/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.1124 - loss: 2.3014 - val_accuracy: 0.1135 - val_loss: 2.3012
# Epoch 8/100
# ...
